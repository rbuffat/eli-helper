# %%
import xml.etree.ElementTree as ET
from io import StringIO
import requests
from collections import OrderedDict
import json
from urllib.parse import urlparse, parse_qsl, urlencode, urlunparse
from ipywidgets import interact, interactive, FloatSlider, interact_manual, HTML

style = """
    <style>
        .output_scroll {
            height: unset !important;
            border-radius: unset !important;
            -webkit-box-shadow: unset !important;
            box-shadow: unset !important;
        }
    </style>
    """
display(HTML(style))


def parse_wms(xml):
    """ Rudimentary parsing of WMS Layers from GetCapabilites Request
        owslib.wms seems to have problems parsing some weird not relevant metadata.
        This function aims at only parsing relevant layer metadata
    """
    wms = {}
    try:
        it = ET.iterparse(StringIO(xml))
        for _, el in it:
            prefix, has_namespace, postfix = el.tag.partition('}')
            if has_namespace:
                el.tag = postfix
        root = it.root
    except:
        raise RuntimeError("Could not parse XML.")

    root_tag = root.tag.rpartition("}")[-1]
    if root_tag in {'ServiceExceptionReport', 'ServiceException'}:
        raise RuntimeError("WMS service exception")

    if root_tag not in {'WMT_MS_Capabilities', 'WMS_Capabilities'}:
        raise RuntimeError("No Capabilities Element present: Root tag: {}".format(root_tag))

    if 'version' not in root.attrib:
        raise RuntimeError("WMS version cannot be identified.")
    version = root.attrib['version']
    wms['version'] = version

    layers = {}

    def parse_layer(element, crs=set(), styles={}):
        new_layer = {'CRS': crs,
                     'Styles': {}}
        new_layer['Styles'].update(styles)
        for tag in ['Name', 'Title', 'Abstract']:
            e = element.find("./{}".format(tag))
            if e is not None:
                new_layer[e.tag] = e.text
        for tag in ['CRS', 'SRS']:
            es = element.findall("./{}".format(tag))
            for e in es:
                new_layer["CRS"].add(e.text.upper())
        for tag in ['Style']:
            es = element.findall("./{}".format(tag))
            for e in es:
                new_style = {}
                for styletag in ['Title', 'Name']:
                    new_style[styletag] = e.find("./{}".format(styletag)).text
                new_layer["Styles"][new_style['Name']] = new_style

        if 'Name' in new_layer:
            layers[new_layer['Name']] = new_layer

        for sl in element.findall("./Layer"):
            parse_layer(sl,
                        new_layer['CRS'].copy(),
                        new_layer['Styles'])

    # Find child layers. CRS and Styles are inherited from parent
    top_layers = root.findall(".//Capability/Layer")
    for top_layer in top_layers:
        parse_layer(top_layer)

    wms['layers'] = layers

    # Parse formats
    formats = []
    for es in root.findall(".//Capability/Request/GetMap/Format"):
        formats.append(es.text)
    wms['formats'] = formats
    
    return wms
# Out:
# HTML(value='\n    <style>\n        .output_scroll {\n            height: unset !important;\n            border…

# %% [markdown]
# # Generating a WMS template
#
# This Jupyter notebook can be used to generate a template using a WMS Server.
#
# Insert a WMS url (e.g. `https://wms.zh.ch/OGDLidarZH?SERVICE=WMS&Request=GetCapabilities`) in the input box below and press enter.

# %%
wms_url = input()

def run_wms_wizard(wms_url):
    wms_args = {}
    u = urlparse(wms_url)
    url_parts = list(u)
    for k, v in parse_qsl(u.query):
        wms_args[k.lower()] = v

    def get_getcapabilitie_url():

        get_capabilities_args = {'service': 'WMS',
                                 'request': 'GetCapabilities'}
        if 'version' in wms_args:
            get_capabilities_args['version'] = wms_args['version']


        # Some server only return capabilities when the map parameter is specified
        if 'map' in wms_args:
            get_capabilities_args['map'] = wms_args['map']

        url_parts[4] = urlencode(list(get_capabilities_args.items()))
        return urlunparse(url_parts)

    url = get_getcapabilitie_url()


    r = requests.get(url)
    xml = r.text
    wms = parse_wms(xml)

    print("Layers:")
    layers = list(wms['layers'].keys())
    for i, layer in enumerate(layers):
        print("{}: {} ({})".format(i,
                                   layers[i],
                                   wms['layers'][layer]['Title']))

    print(" ")
    selected_layer_idx = int(input("Select Layer: "))
    print(" ")

    assert 0 <= selected_layer_idx < len(layers)
    selected_layer = layers[selected_layer_idx]
    description = ''
    if 'Abstract' in wms['layers'][selected_layer]:
        description = wms['layers'][selected_layer]['Abstract']
    layer_title = ''
    if 'Title' in wms['layers'][selected_layer]:
        layer_title = wms['layers'][selected_layer]['Title']

    crs_options = wms['layers'][selected_layer]['CRS']

    styles = list(wms['layers'][selected_layer]['Styles'].keys())
    selected_style = None
    if len(styles) > 0:
        print("Styles:")
        for i, style in enumerate(styles):
            print("{}: {} ({})".format(i, style, (wms['layers'][selected_layer]['Styles'][style]['Title'])))
        print(" ")
        selected_style_idx = int(input("Select Style: "))
        print(" ")

        assert 0 <= selected_style_idx < len(styles)
        selected_style = styles[selected_style_idx]
    else:
        selected_style = ''

    print("Image formats:")
    format_options = wms['formats']
    for i, format_option in enumerate(format_options):
        print("{}: {}".format(i, format_option))

    print(" ")
    selected_format_idx = int(input("Select Format: "))
    print(" ")
    assert 0 <= selected_format_idx < len(format_options)
    selected_format = format_options[selected_format_idx]

    wms_paramters = {}
    wms_paramters['LAYERS'] = selected_layer
    if selected_style is not None:
        wms_paramters['STYLES'] = selected_style
    wms_paramters['FORMAT'] = selected_format
    wms_paramters['CRS'] = '{proj}'
    wms_paramters['WIDTH'] = '{width}'
    wms_paramters['HEIGHT'] = '{height}'
    wms_paramters['BBOX'] = '{bbox}'
    wms_paramters['VERSION'] = wms['version']
    wms_paramters['SERVICE'] = 'WMS'
    wms_paramters['REQUEST'] = 'GetMap'

    baseurl = wms_url.split("?")[0]
    service_url = baseurl + "?" + "&".join(["{}={}".format(key, value) for key, value in wms_paramters.items()])

    result = OrderedDict()
    result['type'] = 'Feature'
    result['properties'] = OrderedDict()
    result['properties']['name'] = layer_title
    result['properties']['type'] = 'wms'
    result['properties']['url'] = service_url
    result['properties']['license_url'] = ''
    result['properties']['privacy_policy_url'] = ''
    result['properties']['id'] = ''
    result['properties']['description'] = description
    result['properties']['country_code'] = ''
    result['properties']['best'] = False
    result['properties']['start_date'] = ''
    result['properties']['end_date'] = ''
    result['properties']['category'] = ''
    result['properties']['available_projections'] = list(crs_options)
    result['properties']['attribution'] = {'url': '',
                                           'text': '',
                                           'html': '',
                                           'required': True}
    result['geometry'] = ''


    print("")
    print("Copy the following output:")
    print("-------------------------")
    print(json.dumps(result,
                     indent=4,
                     sort_keys=False))
    print("-------------------------")

run_wms_wizard(wms_url)
# Out:
# https://wms.geo.gl.ch/?SERVICE=WMS&VERSION=1.3.0&REQUEST=GetCapabilities
# Layers:
# 0: wmspublic (geo.gl.ch)
# 1: ch.gl.basemaps.lk25_1958-1963 (Landeskarte 25 1958-1963)
# 2: ch.gl.basemaps.lk25_1983-1985 (Landeskarte 25 1983-1985)
# 3: ch.gl.naturalhazards.perimeter-gefahrenkartierung (Naturgefahren Perimeter Gefahrenkartierung)
# 4: ch.gl.naturalhazards.gefahrenkarte-synoptisch (Naturgefahren Gefahrenstufen alle Prozesse)
# 5: ch.gl.location.av_fixpunkte (Fixpunkte amtliche Vermessung)
# 6: ch.gl.earthcover.av_projektierte-bbflaechen (Projektierte Bodenbedeckungsflächen amtliche Vermessung)
# 7: ch.gl.earthcover.av_bbflaechen-sw (Bodenbedeckungsflächen schwarz-weiss amtliche Vermessung)
# 8: ch.gl.earthcover.av_bbflaechen-farbig (Bodenbedeckungsflächen farbig amtliche Vermessung)
# 9: ch.gl.earthcover.av_bb-namen (Bodenbedeckung Namen amtliche Vermessung)
# 10: ch.gl.structure.av_eoflaechen-sw (Einzelobjektflächen schwarz-weiss amtliche Vermessung)
# 11: ch.gl.structure.av_eoflaechen-farbig (Einzelobjektflächen farbig amtliche Vermessung)
# 12: ch.gl.structure.av_eolinien (Einzelobjektlinien amtliche Vermessung)
# 13: ch.gl.structure.av_eopunkte (Einzelobjektpunkte amtliche Vermessung)
# 14: ch.gl.structure.av_eo-namen (Einzelobjektnamen amtliche Vermessung)
# 15: ch.gl.location.av_nomenklatur (Nomenklatur Flurnamen Ortsnamen amtliche Vermessung)
# 16: ch.gl.cadastre.av_grenzpunkte (Grenzpunkte amtliche Vermessung)
# 17: ch.gl.cadastre.av_sdr (Selbstständige und dauernde Rechte amtliche Vermessung)
# 18: ch.gl.cadastre.av_grundstuecksnummern (Grundstücksnummern amtliche Vermessung)
# 19: ch.gl.boundaries.av_hoheitsgrenzpunkte (Hoheitsgrenzpunkte amtliche Vermessung)
# 20: ch.gl.boundaries.av_hoheitsgrenzabschnitte (Hoheitsgrenzabschnitte amtliche Vermessung)
# 21: ch.gl.location.av_lokalisationen (Lokalisationen amtliche Vermessung)
# 22: ch.gl.location.av_gebaeudeadressen (Gebäudeadressen amtliche Vermessung)
# 23: ch.gl.cadastre.eigentum-technischebetriebe (Eigentum Technische Betriebe)
# 24: ch.gl.boundaries.grundbuecher (Grundbücher amtliche Vermessung)
# 25: ch.gl.boundaries.gemeinden (Gemeinden GL)
# 26: ch.gl.cadastre.eigentum-gemeinden (Eigentum Gemeinden)
# 27: ch.gl.cadastre.eigentum-bund (Eigentum Bund)
# 28: ch.gl.basemaps.kantonsmaske (Kantonsmaske)
# 29: ch.gl.cadastre.eigentum-kanton (Eigentum Kanton)
# 30: ch.gl.boundaries.av_gemeindegrenzen (Gemeindegrenzen amtliche Vermessung)
# 31: ch.gl.planning.richtplan2018-entwurf (Richtplan 2018 Mitwirkungsentwurf)
# 32: ch.gl.farming.alpnamen (Landwirtschaft Sömmerungsgebiet Alpen Namen)
# 33: ch.gl.farming.bewirtschafter (Landwirtschaft Bewirtschafter Betriebsnummern)
# 34: ch.gl.inlandwaters.erdsondenausschlussbereich (Gewässerschutz Erdsondenausschlussbereich)
# 35: ch.gl.inlandwaters.gsareal (Gewässerschutz Grundwasserschutzareal)
# 36: ch.gl.transportation.schweizmobil_velo (SchweizMobil-Radrouten Velo Fahrrad)
# 37: ch.gl.transportation.wanderwege (Wanderwege)
# 38: ch.gl.utilities.grundwasser-quellfassungen (Grundwasser- und Quellfassungen)
# 39: ch.gl.farming.kulturflaechen (Landwirtschaft Nutzungsarten Kulturflächen)
# 40: ch.gl.farming.soemmerungsgebiet (Landwirtschaft Sömmerungsgebiet Alpen)
# 41: ch.gl.inlandwaters.gsbereich (Gewässerschutzbereich)
# 42: ch.gl.inlandwaters.gszonen (Gewässerschutz Grundwasser-Quellschutzzonen)
# 43: ch.gl.transportation.radrouten-kantonal (Kantonale Radrouten)
# 44: ch.gl.elevation.av-hoehen2016 (Höhenmodell amtliche Vermessung 2016)
# 45: ch.gl.utilities.grundwasservorkommen (Grundwasservorkommen)
# 46: ch.gl.planning.richtplan2004 (Richtplan 2004)
# 47: ch.gl.cadastre.av_grundbuchplan-color (Grundbuchplan farbig)
# 48: ch.gl.cadastre.av_projektierte-grundstuecksnummern (Projektierte Grundstücksnummern amtliche Vermessung)
# 49: ch.gl.cadastre.av_projektierte-sdr (Projektierte selbständige und dauernde Rechte amtliche Vermessung)
# 50: ch.gl.cadastre.av_liegenschaften (Liegenschaften amtliche Vermessung)
# 51: ch.gl.cadastre.av_projektierte-liegenschaften (Projektierte Liegenschaften amtliche Vermessung)
# 52: ch.gl.cadastre.av_grundbuchplan-bw (Grundbuchplan schwarz-weiss)
# 53: ch.gl.planning.np_bauzonen (Nutzungsplanung Bauzonen)
# 54: ch.gl.planning.np_landwirtschaftszonen (Nutzungsplanung Landwirtschaftszonen)
# 55: ch.gl.planning.np_schutzzonen (Nutzungsplanung Schutzzonen ausserhalb Bauzonen)
# 56: ch.gl.planning.np_weitere-zonen (Nutzungsplanung weitere Zonen ausserhalb Bauzonen)
# 57: ch.gl.planning.np_ue-andere-flaechen (Nutzungsplanung andere flächenbezogenen Festlegungen)
# 58: ch.gl.planning.np_ue-zonen (Nutzungsplanung überlagernde Zonen)
# 59: ch.gl.planning.np_ue-linien (Nutzungsplanung linienbezogene Festlegungen)
# 60: ch.gl.planning.np_ue-punkte (Nutzungsplanung punktbezogene Festlegungen)
# 61: ch.gl.location.schwerpunkte (Schwerpunkte des Kantons und der Gemeinden)
# 62: ch.gl.location.ortschaften (Ortschaften)
# 63: ch.gl.location.ortschaftsnamen (Ortschaftsnamen)
# 64: ch.gl.imagery.orthofoto2002 (Luftbild Orthofoto 2002)
# 65: ch.gl.imagery.orthofoto2003 (Luftbild Orthofoto 2003)
# 66: ch.gl.imagery.orthofoto2005 (Luftbild Orthofoto 2005)
# 67: ch.gl.imagery.orthofoto2006 (Luftbild Orthofoto 2006)
# 68: ch.gl.imagery.orthofoto2008 (Luftbild Orthofoto 2008)
# 69: ch.gl.imagery.orthofoto2010 (Luftbild Orthofoto 2010)
# 70: ch.gl.imagery.orthofoto2011 (Luftbild Orthofoto 2011)
# 71: ch.gl.imagery.orthofoto2013 (Luftbild Orthofoto 2013)
# 72: ch.gl.imagery.orthofoto2015 (Luftbild Orthofoto 2015)
# 73: ch.gl.soils.bodeneignung-bodentyp (Bodeneignung - Bodentyp)
# 74: ch.gl.soils.bodeneignung-gruendigkeit (Bodeneignung - Gründigkeit)
# 75: ch.gl.soils.bodeneignung-nutzung-fff (Bodeneignung - Nutzungseignung Fruchtfolgeflächen)
# 76: ch.gl.soils.bodeneignung-wasserhaushalt (Bodeneignung - Wasserhaushalt)
# 77: ch.gl.biota.schutzwald (Schutzwald)
# 78: ch.gl.biota.waldbestand (Waldbestand)
# 79: ch.gl.biota.waldgesellschaften (Waldgesellschaften)
# 80: ch.gl.natureprotection.waldreservate (Naturschutz Waldreservate)
# 81: ch.gl.inlandwaters.revitalisierung-strategische-planung-flaechen (Gewässerrevitalisierung - strategische Planung (Flächen))
# 82: ch.gl.inlandwaters.revitalisierung-strategische-planung-linien (Gewässerrevitalisierung - strategische Planung (Linien))
# 83: ch.gl.inlandwaters.oekomorphologie (Gewässerschutz Gewässer-Ökomorphologie)
# 84: ch.gl.inlandwaters.fischereigewaesser (Fischereigewässer)
# 85: ch.gl.inlandwaters.fischereigewaesser-abschnitte (Fischereigewässer - Abschnitte)
# 86: ch.gl.environmentalprotection.kbs (Kataster der belasteten Standorte - Altlasten)
# 87: ch.gl.natureprotection.unesco-welterbe (Naturschutz UNESCO-Welterbe Tektonikarena Sardona)
# 88: ch.gl.natureprotection.landschaftsverzeichnis (Naturschutz Landschaftsverzeichnis)
# 89: ch.gl.natureprotection.nsg-perimeter (Naturschutzgebiete Perimeter)
# 90: ch.gl.natureprotection.nsg-zonen (Naturschutzgebiete Zonen)
# 91: ch.gl.natureprotection.nhg-vertraege (Naturschutz NHG-Verträge)
# 92: ch.gl.natureprotection.biotope-national (Naturschutz Biotope von nationaler Bedeutung)
# 93: ch.gl.natureprotection.biotope-linien (Naturschutz Biotope (Linien))
# 94: ch.gl.natureprotection.biotope-flaechen (Naturschutz Biotope (Flächen))
# 95: ch.gl.natureprotection.ersatzmassnahmen (Naturschutz Landschaftsschutz: Ersatzmassnahmen)
# 96: ch.gl.natureprotection.wildruhezonen (Wildruhezonen)
# 97: ch.gl.natureprotection.wildruhezonen-routennetz (Routennetz in Wildruhezonen)
# 98: ch.gl.natureprotection.jagdbanngebiete (Jagdbanngebiete)
# 99: ch.gl.structure.lagerbuchnummern (Lagerbuchnummern Gebäudenummern)
# 100: ch.gl.society.isos-ortsbilder (ISOS Ortsbilder)
# 101: ch.gl.society.isos-einzelobjekte (ISOS Einzelobjekte)
# 102: ch.gl.society.kgs-objekte_lokal (Kulturgüterschutz-Objekte lokal)
# 103: ch.gl.society.kgs-objekte_national-regional (Kulturgüterschutz-Objekte national und regional)
# 104: ch.gl.society.denkmalschutzobjekte_punkte (Denkmalschutz Einzelobjekte)
# 105: ch.gl.society.denkmalschutzobjekte_flaechen (Denkmalschutz: Flächenobjekte)
# 106: ch.gl.energy.stromversorgungssicherheit-netzebene7 (Stromversorgungssicherheit Netzebene 7)
# 107: ch.gl.energy.stromversorgungssicherheit-netzebene5b (Stromversorgungssicherheit Netzebene 5b)
# 108: ch.gl.energy.stromversorgungssicherheit-netzebene5a (Stromversorgungssicherheit Netzebene 5a)
# 109: ch.gl.energy.stromversorgungssicherheit-netzebene7-ausnahmen (Stromversorgungssicherheit Ausnahmen Netzebene 7)
# 110: ch.gl.energy.stromversorgungssicherheit-netzebene5b-ausnahmen (Stromversorgungssicherheit Ausnahmen Netzebene 5b)
# 111: ch.gl.energy.stromversorgungssicherheit-netzebene5a-ausnahmen (Stromversorgungssicherheit Ausnahmen Netzebene 5a)
# 112: ch.gl.naturalhazards.baugrundklassen (Naturgefahren Seism. Mikrozonierung - Baugrundklassen)
# 113: ch.gl.naturalhazards.prozessquellen-lawine (Naturgefahren Prozessquellen HPA Lawine)
# 114: ch.gl.naturalhazards.prozessquellen-sturz (Naturgefahren Prozessquellen HPA Sturz)
# 115: ch.gl.naturalhazards.prozessquellen-rutschung (Naturgefahren Prozessquellen HPA Rutschung)
# 116: ch.gl.naturalhazards.prozessquellen-wasser (Naturgefahren Prozessquellen HPA Wasser)
# 117: ch.gl.naturalhazards.gefahrenstufen-lawine (Naturgefahren Gefahrenstufen HPA Lawine)
# 118: ch.gl.naturalhazards.gefahrenstufen-rutschung (Naturgefahren Gefahrenstufen HPA Rutschung)
# 119: ch.gl.naturalhazards.gefahrenstufen-sturz (Naturgefahren Gefahrenstufen HPA Sturz)
# 120: ch.gl.naturalhazards.gefahrenstufen-wasser (Naturgefahren Gefahrenstufen HPA Wasser)
# 121: ch.gl.naturalhazards.intensitaeten-fliesstiefen-100j (Naturgefahren Intensitäten Fliesstiefen 100-jährlich)
# 122: ch.gl.naturalhazards.intensitaeten-fliesstiefen-300j (Naturgefahren Intensitäten Fliesstiefen 300-jährlich)
# 123: ch.gl.naturalhazards.intensitaeten-lawine-030j (Naturgefahren Intensitäten Lawine 30-jährlich)
# 124: ch.gl.naturalhazards.intensitaeten-lawine-100j (Naturgefahren Intensitäten Lawine 100-jährlich)
# 125: ch.gl.naturalhazards.intensitaeten-lawine-300j (Naturgefahren Intensitäten Lawine 300-jährlich)
# 126: ch.gl.naturalhazards.intensitaeten-sturz-030j (Naturgefahren Intensitäten Sturz 30-jährlich)
# 127: ch.gl.naturalhazards.intensitaeten-sturz-100j (Naturgefahren Intensitäten Sturz 100-jährlich)
# 128: ch.gl.naturalhazards.intensitaeten-sturz-300j (Naturgefahren Intensitäten Sturz 300-jährlich)
# 129: ch.gl.naturalhazards.intensitaeten-rutschung-030j (Naturgefahren Intensitäten Rutschung 30-jährlich)
# 130: ch.gl.naturalhazards.intensitaeten-rutschung-100j (Naturgefahren Intensitäten Rutschung 100-jährlich)
# 131: ch.gl.naturalhazards.intensitaeten-rutschung-300j (Naturgefahren Intensität Rutschung 300-jährlich)
# 132: ch.gl.naturalhazards.intensitaeten-wasser-030j (Naturgefahren Intensitäten Wasser 30-jährlich)
# 133: ch.gl.naturalhazards.intensitaeten-wasser-100j (Naturgefahren Intensitäten Wasser 100-jährlich)
# 134: ch.gl.naturalhazards.intensitaeten-wasser-300j (Naturgefahren Intensitäten Wasser 300-jährlich)
# 135: ch.gl.structure.gebaeudeinformation (Gebäudeinformation)
# 136: ch.gl.structure.gebaeude_wohnungs_register (Gebäude- und Wohnungsregister (GWR))
# 137: ch.gl.biota.waldrand-hotspot (Waldrandgebiete Hotspot)
# 138: ch.gl.society.wald-erholungsfunktion (Erholungsfunktion im Wald)
# 139: ch.gl.location.adr_hausnummern (Adressierung Hausnummern)
# 140: ch.gl.location.adr_strassenstuecke (Adressierung Strassenstücke)
# 141: ch.gl.location.adr_hausnr-zu-strassen (Adressierung Zuordnung Haus-Nr. zu Strassen)
# 142: ch.gl.location.adr_benannte-gebiete (Adressierung benannte Gebiete)
# 143: ch.gl.location.flurnamen (Flurnamen)
# 144: ch.gl.farming.bienenstandorte (Landwirtschaft Bienenstandorte)
# 145: ch.gl.farming.landschaftsqualitaet-punkte (Landwirtschaft Landschaftsqualität Punkte)
# 146: ch.gl.farming.landschaftsqualitaet-linien (Landwirtschaft Landschaftsqualität Linien)
# 147: ch.gl.farming.landschaftsqualitaet-flaechen (Landwirtschaft Landschaftsqualität Flächen)
# 148: ch.gl.basemaps.stadtplan-glarus_1861 (Stadtplan von Glarus 1861 (vor dem Brand))
# 149: ch.gl.basemaps.stadtplan-glarus_1964 (Stadtplan von Glarus 1964)
# 150: ch.gl.structure.alt-glarus_av-gebaeude (Gebäudegrundrisse amtliche Vermessung Glarus)
# 151: ch.gl.planning.gwn_fliessgewaesser-ohne-breite-aus-av (Gewässerraum-Ausscheidung: Fliessgewässer (ohne Breite gem. AV))
# 152: ch.gl.planning.gwn_fliessgewaesser-bearbeitet-nach-av (Gewässerraum-Ausscheidung: Fliessgewässer (bearbeitet nach AV))
# 153: ch.gl.planning.gwn_stehende-gewaesser (Gewässerraum-Ausscheidung: stehende Gewässer)
# 154: ch.gl.planning.gewr_schutzgebiete-2013 (Gewässerraum-Ausscheidung: Schutzgebiete 2013)
# 155: ch.gl.planning.gewr_fliessgewaesser-schutzgebiete (Gewässerraum-Ausscheidung: GewR für Fliessgewässer in Schutzgebieten)
# 156: ch.gl.planning.gewr_fliessgewaesser-schutzgebiete-ohne-breite-aus-av (Gewässerraum-Ausscheidung: GewR für Fliessgewässer in Schutzgebieten (ohne Breite gem. AV))
# 157: ch.gl.planning.gewr_fliessgewaesser-umhuellende (Gewässerraum-Ausscheidung: GewR für Fliessgewässer)
# 158: ch.gl.planning.gewr_fliessgewaesser-umhuellende-ohne-breite-aus-av (Gewässerraum-Ausscheidung: GewR für Fliessgewässer (ohne Breite gem. AV))
# 159: ch.gl.planning.gewr_fliessgewaesser (Gewässerraum-Ausscheidung: GewR für Fliessgewässer)
# 160: ch.gl.planning.gewr_fliessgewaesser-ohne-breite-aus-av (Gewässerraum-Ausscheidung: GewR für Fliessgewässer (ohne Breite gem. AV))
# 161: ch.gl.planning.gewr_stehende-gewaesser (Gewässerraum-Ausscheidung: GewR für stehende Gewässer)
# 162: ch.gl.planning.gewr_geloeschte-objekte (Gewässerraum-Ausscheidung: gelöschte Objekte)
# 163: ch.gl.basemaps.swissmapraster25-farbig (Landeskarte Swiss Map Raster 25 (farbig))
# 164: ch.gl.basemaps.swissmapraster25-grau (Landeskarte Swiss Map Raster 25 (grau))
# 165: ch.gl.basemaps.swissmapraster50-farbig (Landeskarte Swiss Map Raster 50 (farbig))
# 166: ch.gl.basemaps.swissmapraster50-grau (Landeskarte Swiss Map Raster 50 (grau))
# 167: ch.gl.basemaps.swissmapraster100-farbig (Landeskarte Swiss Map Raster 100 (farbig))
# 168: ch.gl.basemaps.swissmapraster100-grau (Landeskarte Swiss Map Raster 100 (grau))
# 169: ch.gl.cadastre.oeffentliches-grundeigentum (Öffentliches Grundeigentum)
# 170: ch.gl.basemaps.av_situation-bw (Situation und Einzelobjekte amtliche Vermessung)
# 171: ch.gl.society.alt-glarus_poi (Glarus vor dem Brand 1861: Points-of-Interest)
# 172: ch.gl.earthcover.arealstatistik (Arealstatistik der Grundstücke)
# 173: ch.gl.society.alt-glarus (Das alte Glarus)
# 174: ch.gl.basemaps.stadtplan-glarus_1911 (Stadtplan von Glarus 1911)
# 175: ch.gl.imagery.orthofoto2017 (Luftbild Orthofoto 2017)
# 176: ch.gl.planning.np-1632_grundnutzung-zonenflaeche (Nutzungsplanung Glarus Grundnutzung Zonenfläche)
# 177: ch.gl.planning.np-1632_ueberlagernde-festlegung (Nutzungsplanung Glarus überlagernde Festlegung)
# 178: ch.gl.planning.np-1632_linienbezogene-festlegung (Nutzungsplanung Glarus linienbezogene Festlegung Baulinie)
# 179: ch.gl.planning.np-1632_objektbezogene-festlegung (Nutzungsplanung Glarus objektbezogene Festlegungen)
# 180: ch.gl.planning.np-1632_laermempfindlichkeitsstufen (Nutzungsplanung Glarus Lärmempfindlichkeitsstufen LES)
# 181: ch.gl.planning.zonenplan-glarus (Nutzungsplanung Zonenplan Glarus)
# 182: ch.gl.biota.waldgrenzen-1632 (Statische Waldgrenzen Glarus)
# 183: ch.gl.planning.richtplan2018-genehmigung-okt18 (Richtplan 2018 Genehmigungsentwurf Okt. 2018)
# 184: ch.gl.natureprotection.invasive-neophyten (Invasive Neophyten)
# 185: ch.gl.natureprotection.invasive-neophyten-vorjahre (Invasive Neophyten - Zustand Vorjahre)
# 186: ch.gl.society.barrierefreier-zugang (Barrierefreier Zugang, Rollstuhlgängigkeit)
# 187: ch.gl.society.rollstuhlparkplaetze (Barrierefreiheit Rollstuhlparkplätze)
# 188: ch.gl.society.rollstuhl-wc (Barrierefreiheit Rollstuhl-WC)
# 189: ch.gl.transportation.waldstrassen (Waldstrassen)
# 190: ch.gl.society.barrierefreiheit-angebote (Barrierefreiheit Angebote Anlagen Einrichtungen)
# 191: ch.gl.society.glarnerland-barrierefrei (Glarnerland barrierefrei)
# 192: ch.gl.society.nicht-barrierefreier-zugang (Nicht barrierefreier Zugang, Rollstuhlgängigkeit)
# 193: ch.gl.natureprotection.waldperlen (Waldreservate Waldperlen)
# 194: ch.gl.society.glarner-waldperlen (Glarner Waldperlen Waldreservate Toggi)
# 195: ch.gl.planning.np-1630_grundnutzung-zonenflaeche (Nutzungsplanung Glarus Nord Grundnutzung Zonenfläche (BESCHLUSS))
# 196: ch.gl.planning.np-1630_ueberlagernde-festlegung (Nutzungsplanung Glarus Nord überlagernde Festlegung (BESCHLUSS))
# 197: ch.gl.planning.np-1630_linienbezogene-festlegung (Nutzungsplanung Glarus Nord linienbezogene Festlegung (BESCHLUSS))
# 198: ch.gl.planning.np-1630_objektbezogene-festlegung (Nutzungsplanung Glarus Nord objektbezogene Festlegung (BESCHLUSS))
# 199: ch.gl.planning.np-1630_laermempfindlichkeitsstufen (Nutzungsplanung Glarus Nord Lärmempfindlichkeitsstufen LES (BESCHLUSS))
# 200: ch.gl.basemaps.swissmapraster10-farbig (Landeskarte Swiss Map Raster 10 (farbig))
# 201: ch.gl.biota.waldgrenzen-1630 (Statische Waldgrenzen Glarus Nord)
# 202: ch.gl.basemaps.swissmapraster10-grau (Landeskarte Swiss Map Raster 10 (grau))
# 203: ch.gl.planning.np-1630_waldabstandslinien (Nutzungsplanung Glarus Nord Waldabstandslinien (BESCHLUSS))
# 204: ch.gl.planning.zonenplan-glarus-nord (Nutzungsplanung Zonenplan Glarus Nord (BESCHLUSS))
# 205: ch.gl.transportation.kantonsstrassen (Strassenverzeichnis Kantonsstrassen)
# 206: ch.gl.transportation.kantonsstrassen_abschnitte (Strassenverzeichnis Kantonsstrassen Abschnitte)
# 207: ch.gl.biota.oereb_waldgrenzen (ÖREB-Kataster: statische Waldgrenzen)
# 208: ch.gl.planning.oereb_waldabstandslinien (ÖREB-Kataster: Waldabstandslinien)
# 209: ch.gl.planning.oereb_laermempfindlichkeitsstufen (ÖREB-Kataster: Lärmempfindlichkeitsstufen)
# 210: ch.gl.inlandwaters.oereb_grundwasserschutzzonen (ÖREB-Kataster: Grundwasserschutzzonen)
# 211: ch.gl.structure.av_eoflaechen_oereb (ÖREB-Kataster: Einzelobjektflächen AV für Planauszug)
# 212: ch.gl.earthcover.av_bbflaechen_oereb (ÖREB-Kataster: Bodenbedeckungsflächen AV)
# 213: ch.gl.cadastre.av_grundbuchplan-oereb (ÖREB-Kataster: Grundbuchplan AV Planauszug)
# 214: ch.gl.biota.multifunktionaler-wald (Multifunktionaler Wald)
# 215: ch.gl.cadastre.av_grundstuecke (Grundstücke (Liegenschaften, SDR) der amtlichen Vermessung)
# 216: ch.gl.cadastre.av_projektierte-grundstuecke (Projektierte Grundstücke (Liegenschaften, SDR) der amtlichen Vermessung)
# 217: ch.gl.planning.richtplan2018-genehmigung-aug19 (Richtplan 2018 Genehmigungsentwurf Aug. 2019)
# 218: ch.gl.transportation.schweizmobil_mtb (SchweizMobil-Mountainbikerouten MTB)
# 219: ch.gl.transportation.schweizmobil_wandern (SchweizMobil-Wanderrouten)
# 220: ch.gl.cadastre.grundeigentum (Grundeigentum)
# 221: ch.gl.transportation.schweizmobil (SchweizMobil: Wandern, Velo, Mountainbike)
# 222: ch.gl.planning.sondernutzungsplaene (Sondernutzungsplan Baulinienplan Überbauungsplan)
# 223: ch.gl.planning.oereb_sondernutzungsplaene (ÖREB-Kataster: Sondernutzungspläne)
# 224: ch.gl.elevation.av-hoehen2019 (Höhenmodell amtliche Vermessung 2019)
# 225: ch.gl.transportation.landesfussweg (Landesfussweg)
# 226: ch.gl.transporation.ausnahmetransport_route (Ausnahmetransportrouten Routen)
# 227: ch.gl.transportation.ausnahmetransport_hindernis (Ausnahmetransportrouten Hindernis)
# 228: ch.gl.planning.fruchtfolgeflaechen (Fruchtfolgeflächen (FFF))
# 229: ch.gl.basemaps.uebersichtskarte (Übersichtskarte Kanton Glarus)
# 230: ch.gl.inlandwaters.grundwasser-isohypsen (Grundwasser-Mittelstand Isohypsen)
# 231: ch.gl.planning.np-1631_grundnutzung-zonenflaeche (Nutzungsplanung Glarus Süd Grundnutzung Zonenfläche (MITWIRKUNG))
# 232: ch.gl.planning.np-1631_ueberlagernde-festlegung (Nutzungsplanung Glarus Süd überlagernde Festlegung (MITWIRKUNG))
# 233: ch.gl.planning.np-1631_linienbezogene-festlegung (Nutzungsplanung Glarus Süd linienbezogene Festlegung (MITWIRKUNG))
# 234: ch.gl.planning.np-1631_objektbezogene-festlegung (Nutzungsplanung Glarus Süd objektbezogene Festlegung (MITWIRKUNG))
# 235: ch.gl.planning.np-1631_laermempfindlichkeitsstufen (Nutzungsplanung Glarus Süd Lärmempfindlichkeitsstufen LES (MITWIRKUNG))
# 236: ch.gl.planning.zonenplan-glarus-sued (Nutzungsplanung Zonenplan Glarus Süd (MITWIRKUNG))
# 237: ch.gl.biota.waldgrenzen-1631 (Statische Waldgrenzen Glarus Süd)
# 238: ch.gl.location.flurnamenkarte-glarus_10000 (Flurnamenkarte Glarus 1:10'000)
# 239: ch.gl.location.flurnamenkarte-glarus_5000 (Flurnamenkarte Glarus 1:5'000 (Stadtgebiet))
# 240: ch.gl.location.flurnamenkarte-glarus (Flurnamenkarte Glarus)
# 241: ch.gl.location.flurnamenkarte-glarus_lokalnamen (Flurnamenkarte Glarus Lokalnamen)
# 242: ch.gl.location.adr_plz-gebiete (Postleitzahl-Gebiete PLZ)
# 243: ch.gl.energy.stromversorgungssicherheit-netzebene3 (Stromversorgungssicherheit Netzebene 3)
# 244: ch.gl.imagery.orthofoto2019 (Luftbild Orthofoto 2019)
# Select Layer: 244
#
# Styles:
# 0: default (default)
#
# Select Style: 0
#
# Image formats:
# 0: image/jpeg
# 1: image/png
# 2: image/png; mode=16bit
# 3: image/png; mode=8bit
# 4: image/png; mode=1bit
# 5: application/dxf
#
# Select Format: 0
#
#
# Copy the following output:
# -------------------------
# {
#     "type": "Feature",
#     "properties": {
#         "name": "Luftbild Orthofoto 2019",
#         "type": "wms",
#         "url": "https://wms.geo.gl.ch/?LAYERS=ch.gl.imagery.orthofoto2019&STYLES=default&FORMAT=image/jpeg&CRS={proj}&WIDTH={width}&HEIGHT={height}&BBOX={bbox}&VERSION=1.3.0&SERVICE=WMS&REQUEST=GetMap",
#         "license_url": "",
#         "privacy_policy_url": "",
#         "id": "",
#         "description": "",
#         "country_code": "",
#         "best": false,
#         "start_date": "",
#         "end_date": "",
#         "category": "",
#         "available_projections": [
#             "EPSG:3857",
#             "EPSG:2056",
#             "CRS:84",
#             "EPSG:4326",
#             "EPSG:21781"
#         ],
#         "attribution": {
#             "url": "",
#             "text": "",
#             "html": "",
#             "required": true
#         }
#     },
#     "geometry": ""
# }
# -------------------------
